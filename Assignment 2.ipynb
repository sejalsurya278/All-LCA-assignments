# %%
#Assignment 2- program to find the largest of 3 numbers

int1=int(input("\nenter first number"))
int2=int(input("\nenter second number"))
int3=int(input("\nenter third number"))

if int1>=int2 and int1>=int3 :
    print("\n1st number is the largest")
elif int2>=int3 and int2>=int3 :
     print("\n2nd number is the largest")
else :
    print("\n3rd number is the largest")
# Out:
# enter first number 67
#
# enter second number 2
#
# enter third number 455
# 3rd number is the largest
