# %%
# Assignment 
# create Dictionary, Tuple and list of students and perform add, delete and update


#list
student_list=["sejal","arnav","om","shiv"]
print("\nstudent list:",student_list)
# Out:
# student list: ['sejal', 'arnav', 'om', 'shiv']

# %%
#tuple
student_tuple=("sejal","arnav","om","shiv")
print("\nstudent tuple",student_tuple)
# Out:
# student tuple ('sejal', 'arnav', 'om', 'shiv')

# %%
#dictionary
student_dict={
    101:"sejal",
    102:"arnav",
    103:"arnavi",
    104:"shiv",
    105:"varun"
}
print("\nstudent dictionary:",student_dict)
# Out:
# student dictionary: {101: 'sejal', 102: 'arnav', 103: 'arnavi', 104: 'shiv', 105: 'varun'}

# %%
#after adding a name in dictionary
student_dict[106]="eren"
print("\nafter adding a name in dictionary",student_dict)
# Out:
# after adding a name in dictionary {101: 'sejal', 102: 'arnav', 103: 'arnavi', 104: 'shiv', 105: 'varun', 106: 'eren'}

# %%
#after updating a name in dictionary
student_dict[103]="parvati"
print("\nafter updating a name in dictionary",student_dict)
# Out:
# after updating a name in dictionary {101: 'sejal', 102: 'arnav', 103: 'parvati', 104: 'shiv', 105: 'varun', 106: 'eren'}

# %%
#after deleting a name in dictionary
del student_dict[105]
print("\nafter deleting a name from dictionary",student_dict)
# Out:
# after deleting a name from dictionary {101: 'sejal', 102: 'arnav', 103: 'parvati', 104: 'shiv', 106: 'eren'}
